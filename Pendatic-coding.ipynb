# %% [markdown]
# Add additional fries and drinks to the order if the customer would buy a Cheese Burger Deluxe and add a Sundae instead if they also do. Always remember to print the receipt for every transaction.
#
# p - Add additional fries to the order
# q - Add aditional drinks to the order
# r - customer buy a cheese burger deluxe
# s - Add a sundae to the order
# t - print the receipt for every transaction.
#
# ![wff.PNG](attachment:81132029-17fc-4297-a115-faff665f207f.PNG)
#
# ![flow chart.PNG](attachment:0a964745-fb4e-4866-841b-ba8ff0b0c8a5.PNG)

# %%
cus_order = True
che_burger = True
if(cus_order):
    print("You ordered Cheese Burger Deluxe")
    if(che_burger):
        print("Add additional fries and drinks to the order")
    else:
        print("Add sundae to the order")
else:
    print("other order")
print("receipt printed!")
# Out:
# You ordered Cheese Burger Deluxe
# Add additional fries and drinks to the order
# receipt printed!
